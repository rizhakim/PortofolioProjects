# %%
import pandas as pd
import numpy as np
import pathlib
import os

# %%
#Decide folder path
folder_path = "E:/Temporary/NCR/"

#Make list of file
files = os.listdir(folder_path)

#Make list of file with folder path
excel_list = []
for file in files:
    excel_list.append(folder_path+file)
    
#Initialize an empty DataFrame for Combining Excel
df_combine = pd.DataFrame()

#Using for loop to cleaning each excel file then combining
for file in excel_list:
    
    #import excel file, set header as number
    df = pd.read_excel(file, header= None)
    
    #delete null (NaN) rows based on column no. 7 (column no.7 must be filled in this case)
    df.drop(df[df[7].isnull()].index, inplace = True)
    
    #reset index number
    df = df.reset_index(drop=True)

    #Set column name to the first row
    df.columns = df.iloc[0,:]

    #delete row not header, first row still present
    df.drop(df[df['NO']=='NO'].index, inplace = True)

    #selecting important columns 
    df = df[['NO','DATE','CLASS','SIZE','PRODUK', 'MC', 'PROBLEM', 'REASON']]

    #Concat or adding each result of dataframe to combined dataframe
    df_combine = df_combine.append(df)
    
df_combine
# Out:
# E:\Temporary\Portable Apps\JupyterLab-Portable-3.1.0-3.9\apps\lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# E:\Temporary\Portable Apps\JupyterLab-Portable-3.1.0-3.9\apps\lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# E:\Temporary\Portable Apps\JupyterLab-Portable-3.1.0-3.9\apps\lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
# 0     NO                 DATE      CLASS   SIZE     PRODUK      MC  \
# 1      1  2023-01-02 00:00:00    DRAWING     11  NB : 5/03    AL95
# 2      2  2023-01-03 00:00:00     PC BAR      9  9E21540-2    NSL5
# 3    NaN  2023-01-03 00:00:00     PC BAR      9  9E21545-1    NSL5
# 4    NaN  2023-01-03 00:00:00     PC BAR      9  9E21547-2    NSL5
# ...

# %%
#exporting to excel file
df_combine.to_excel(r"E:\Temporary\NCR\Combined NCR Data.xlsx")
